# %% [markdown]
# ## Project Neighborhood
# This project involves scraping a webpage to get list of coordinates of Barcelona barios and use those coordinates to match the neighborhoods in Foursquare API.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import json
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # to convert address in latitude and longitude value
# for plotting     
import matplotlib.cm as cm
import matplotlib.colors as colors
# for K-means clustering
from sklearn.cluster import KMeans
# for mapping with folium
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
from sklearn import preprocessing
print('Libraries imported')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.16.0                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Libraries imported

# %% [markdown]
# The above cell takes care of the necessary libraries that need to be imported. The next step is to download the link and store the URL into the object wikipedia_link

# %% [markdown]
# Now, since the necessary libraries are imported we are going to import the data of Barcelona districts and their respective coordinates. The list of postal codes and their
# respective coordinates have been obtained courtesy of the website: https://www.aggdata.com/free/spain-postal-codes in a csv format. However this data consists of all the places in deifferent states in Spain, we will only use the ones for Barcelona. We will use this data as a dataframe
# for our analysis. We will use the following line of code to import it as dataframe from the data downloaded from internet and uploaded to the watson server

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Postal Code       Place Name       State County   City  Latitude  Longitude
# 0         1001  Vitoria-Gasteiz  Pais Vasco     PV  Álava   42.8500    -2.6667
# 1         1002  Vitoria-Gasteiz  Pais Vasco     PV  Álava   42.8500    -2.6667
# 2         1003  Vitoria-Gasteiz  Pais Vasco     PV  Álava   42.8500    -2.6667
# 3         1004  Vitoria-Gasteiz  Pais Vasco     PV  Álava   42.8500    -2.6667
# 4         1005  Vitoria-Gasteiz  Pais Vasco     PV  Álava   42.8435    -2.6748

# %% [markdown]
# Now, the dataframe is filtered for only for the City of Barcelona

# %%
barna_df = df_data_1[df_data_1['City']=='Barcelona']
barna_df = barna_df.reset_index(drop=True)
barna_df.head()
# Out:
#    Postal Code Place Name     State County       City  Latitude  Longitude
# 0         8001  Barcelona  Cataluna     CT  Barcelona   41.3818     2.1685
# 1         8002  Barcelona  Cataluna     CT  Barcelona   41.3838     2.1744
# 2         8003  Barcelona  Cataluna     CT  Barcelona   41.3862     2.1799
# 3         8004  Barcelona  Cataluna     CT  Barcelona   41.3765     2.1669
# 4         8005  Barcelona  Cataluna     CT  Barcelona   41.3944     2.1874

# %% [markdown]
# Lets see how the postal codes look like in a map of Barcelona

# %%
address    = 'Barcelona, Spain'
geolocator = Nominatim()
location   = geolocator.geocode(address)
latitude   = location.latitude
longitude  = location.longitude

print('The coordinates of Barcelona are {}, {}.'.format(latitude, longitude))

map_barna= folium.Map(location=[latitude,longitude], zoom_start=12)

#adding markers to the Map
for lat, long, label in zip(barna_df['Latitude'], barna_df['Longitude'], barna_df['Place Name']):
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
    [lat,long],
    radius=5,
    popup=label,
    colour='blue',
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_barna)

map_barna
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/geopy/geocoders/osm.py:138: UserWarning: Using Nominatim with the default "geopy/1.16.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The coordinates of Barcelona are 41.3828939, 2.1774322.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As we can see from the map that Barcelona postal codes also include the suburbs and small towns which fall under the bigger city of Barcelona. However we are only interested in the main city of Barcelona. So will filter only those areas of the city. Further we will rename the place name ( which is same for all the 'barios' in the above dataframe ) to the actual 'barios' names matching with a different dataset

# %%
barna_df =barna_df.loc[barna_df['Place Name'].isin(['Barcelona'])]
barna_df =barna_df.reset_index(drop=True)

# %%
barna_df.head()
# Out:
#    Postal Code Place Name     State County       City  Latitude  Longitude
# 0         8001  Barcelona  Cataluna     CT  Barcelona   41.3818     2.1685
# 1         8002  Barcelona  Cataluna     CT  Barcelona   41.3838     2.1744
# 2         8003  Barcelona  Cataluna     CT  Barcelona   41.3862     2.1799
# 3         8004  Barcelona  Cataluna     CT  Barcelona   41.3765     2.1669
# 4         8005  Barcelona  Cataluna     CT  Barcelona   41.3944     2.1874

# %%
barna_df.drop(['State','County','City'],axis=1,inplace=True)

# %%
barna_df.shape
# Out:
# (45, 4)

# %% [markdown]
# Manually, we will insert the names of Place Names with their actual names using google map reference. ( It is done manually because there is no concise data available for all the districts poste code wise and also since the number of post codes are not many, it is feasible )

# %%
barna_df['Place Name'][0]='El Raval'
barna_df['Place Name'][1]='Gothic Quarter' 
barna_df['Place Name'][2]='Ciutat Vella, La Barcelonata'
barna_df['Place Name'][3]='El Poble Sec' 
barna_df['Place Name'][4]='El Poble Nou'
barna_df['Place Name'][5]='Sant Gervasi, Hospital Plato' 
barna_df['Place Name'][6]='City Center, Passeig de Gracia'
barna_df['Place Name'][7]='Diagonal' 
barna_df['Place Name'][8]='Girona, Jardins de Jaume Perich, Carrer d\'Arago'
barna_df['Place Name'][9]='placa de Tetuan, Urquinaona' 
barna_df['Place Name'][10]='Urgell,Jardin de Cesar Martinell'
barna_df['Place Name'][11]='Vila de Gracia' 
barna_df['Place Name'][12]='Fort Pienc, Sagrada Familia'
barna_df['Place Name'][13]='Sants, Taragona, Placa del Centre' 
barna_df['Place Name'][14]='Sant Antoni, Rocafort'
barna_df['Place Name'][15]='Porta,Virrei Amat, La prosperitat ' 
barna_df['Place Name'][16]='Vallvidrera'
barna_df['Place Name'][17]='Sant Marti, La Verneda, Glories, Arc de Triomf' 
barna_df['Place Name'][18]='El Besos I El Maresme, Paolo Alto Market'
barna_df['Place Name'][19]='La Verneda I La Pau, Sant Marti de Provencals' 
barna_df['Place Name'][20]='Sant Gervasi-Galvany, La Bonanova, Turo Parc'
barna_df['Place Name'][21]='Sant Gervasi-La Bonanova, Av. Tibidabo,  El Putxet' 
barna_df['Place Name'][22]='Vallcarca I Els Penitents, El parc del Turo del Putxet, El Coll'
barna_df['Place Name'][23]='Gracia, Can Baro, Alfons X' 
barna_df['Place Name'][24]='El Baix Guinardo, El Camp D\'En Grassot I Gracia  Nova'
barna_df['Place Name'][25]='El Camp de L\'Arpa del Clot' 
barna_df['Place Name'][26]='La Sagrega'
barna_df['Place Name'][27]='Les Corts, La Maternitat I Sant Ramon, Sants-Montjuic' 
barna_df['Place Name'][28]='La Nova Esquerra de L\'Exiample, Entenca'
barna_df['Place Name'][29]='Sant Adreu, Baro de Viver' 
barna_df['Place Name'][30]='Vilapicina, Can Peguera, El Turo de La Peira'
barna_df['Place Name'][31]='El Carmel, Horta, La Font D\'En Fargues' 
barna_df['Place Name'][32]='La Trinitat Nova, Trinitat Vella, Torre Baro, Vallbona'
barna_df['Place Name'][33]='Saria, Pedralbes, Ciutat Universitaria' 
barna_df['Place Name'][34]='Horta, Sant Genis Dels Agudells, La Teixonera'
barna_df['Place Name'][35]='Hospital Clinic, La Fira' 
barna_df['Place Name'][36]='Verdaguer, Passeig de Sant Joan'
barna_df['Place Name'][37]='Parc de Montjuic, La Marina de Port, La Marina del Prat Vermell' 
barna_df['Place Name'][38]='Port de Barcelona'
barna_df['Place Name'][39]='Zona Franca' 
barna_df['Place Name'][40]='El Guinardo'
barna_df['Place Name'][41]='Les Roquetes'

# %%
barna_df.drop(barna_df.index[42], inplace=True)

# %%
barna_df.drop(barna_df.index[42], inplace=True)

# %%
barna_df.drop(barna_df.index[42], inplace=True)

# %%
barna_df = barna_df.rename(columns={"Place Name": "Neighborhood"})
barna_df.head()
# Out:
#    Postal Code                  Neighborhood  Latitude  Longitude
# 0         8001                      El Raval   41.3818     2.1685
# 1         8002                Gothic Quarter   41.3838     2.1744
# 2         8003  Ciutat Vella, La Barcelonata   41.3862     2.1799
# 3         8004                  El Poble Sec   41.3765     2.1669
# 4         8005                  El Poble Nou   41.3944     2.1874

# %% [markdown]
# Login to Foursquare API and get the requests

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# Lets check a data from Foursquare request

# %%
#creating url and requesiting the API data
neighborhood_lng = barna_df.loc[0, 'Longitude']
neighborhood_lat = barna_df.loc[0, 'Latitude']
radius = 500
Query   = 'coffee'
#create request
url='https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&query={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    API_VERSION,
    neighborhood_lat,
    neighborhood_lng,
    radius,
    LIMIT,
    Query)
results = requests.get(url).json()

# %% [markdown]
# Now, Lets get all the venues

# %%
def getNearbyvenues( names, latitudes, longitudes, radius = 500 ):
    
    venues_list=[]
    for name, lat, lng, in zip( names, latitudes, longitudes ):
        print(name)
        #create request
        url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID,
            CLIENT_SECRET,
            API_VERSION,
            lat,
            lng,
            radius,
            LIMIT)
        
        #make get request
        results=requests.get(url).json()["response"]['groups'][0]['items']
      
        #returning only the relevant information
        venues_list.append([(name,lat,lng,v['venue']['name'],v['venue']['location']['lat'],v['venue']['location']['lng'],
                             v['venue']['categories'][0]['name'], v['venue']['id'] ) for v in results])
        
        nearby_venues= pd.DataFrame([item for venue_list in venues_list for item in venue_list])
        nearby_venues.columns=['Neighbourhood',
                               'Neighbourhood latitude',
                               'Neighbourhood longitude',
                               'Venue',
                               'Venue Latitude',
                               'Venue Longitude',
                               'Venue category',
                               'Id']
    return(nearby_venues)

# %%
barcelona_venues=getNearbyvenues(names=barna_df['Neighborhood'], latitudes=barna_df['Latitude'],longitudes=barna_df['Longitude'])
# Out:
# El Raval
# Gothic Quarter
# Ciutat Vella, La Barcelonata
# El Poble Sec
# El Poble Nou
# Sant Gervasi, Hospital Plato
# City Center, Passeig de Gracia
# Diagonal
# Girona, Jardins de Jaume Perich, Carrer d'Arago
# placa de Tetuan, Urquinaona
# Urgell,Jardin de Cesar Martinell
# Vila de Gracia
# Fort Pienc, Sagrada Familia
# Sants, Taragona, Placa del Centre
# Sant Antoni, Rocafort
# Porta,Virrei Amat, La prosperitat
# Vallvidrera
# Sant Marti, La Verneda, Glories, Arc de Triomf
# El Besos I El Maresme, Paolo Alto Market
# La Verneda I La Pau, Sant Marti de Provencals
# Sant Gervasi-Galvany, La Bonanova, Turo Parc
# Sant Gervasi-La Bonanova, Av. Tibidabo,  El Putxet
# Vallcarca I Els Penitents, El parc del Turo del Putxet, El Coll
# Gracia, Can Baro, Alfons X
# El Baix Guinardo, El Camp D'En Grassot I Gracia  Nova
# El Camp de L'Arpa del Clot
# La Sagrega
# Les Corts, La Maternitat I Sant Ramon, Sants-Montjuic
# La Nova Esquerra de L'Exiample, Entenca
# Sant Adreu, Baro de Viver
# Vilapicina, Can Peguera, El Turo de La Peira
# El Carmel, Horta, La Font D'En Fargues
# La Trinitat Nova, Trinitat Vella, Torre Baro, Vallbona
# Saria, Pedralbes, Ciutat Universitaria
# Horta, Sant Genis Dels Agudells, La Teixonera
# Hospital Clinic, La Fira
# Verdaguer, Passeig de Sant Joan
# Parc de Montjuic, La Marina de Port, La Marina del Prat Vermell
# Port de Barcelona
# Zona Franca
# El Guinardo
# Les Roquetes

# %%
barcelona_venues.head()
# Out:
#   Neighbourhood  Neighbourhood latitude  Neighbourhood longitude  \
# 0      El Raval                 41.3818                   2.1685
# 1      El Raval                 41.3818                   2.1685
# 2      El Raval                 41.3818                   2.1685
# 3      El Raval                 41.3818                   2.1685
# 4      El Raval                 41.3818                   2.1685
#
#                   Venue  Venue Latitude  Venue Longitude    Venue category  \
# 0  La Central del Raval       41.383586         2.168949         Bookstore
# 1              Chivuo's       41.382961         2.169948    Sandwich Place
# 2                  Llop       41.381849         2.169511        Restaurant
# 3             Caravelle       41.382337         2.168818        Restaurant
# 4             A Tu Bola       41.380096         2.169054  Tapas Restaurant
#
#                          Id
# 0  4b71cd74f964a5204b5d2de3
# 1  567873b9498e9f35c38e192e
# 2  59de559766fc6558b0956589
# 3  5040f5e5e4b06be18fa8af73
# 4  52ffc95e498e5f219673b9d1

# %%
barcelona_venues.groupby('Neighbourhood').count().head() #counting the number of venues in each neighborhood
# Out:
#                                                     Neighbourhood latitude  \
# Neighbourhood
# City Center, Passeig de Gracia                                         100
# Ciutat Vella, La Barcelonata                                           100
# Diagonal                                                               100
# El Baix Guinardo, El Camp D'En Grassot I Gracia...                     100
# El Besos I El Maresme, Paolo Alto Market                                57
#
#                                                     Neighbourhood longitude  \
# Neighbourhood
# City Center, Passeig de Gracia                                          100
# Ciutat Vella, La Barcelonata                                            100
# Diagonal                                                                100
# El Baix Guinardo, El Camp D'En Grassot I Gracia...                      100
# El Besos I El Maresme, Paolo Alto Market                                 57
#
#                                                     Venue  Venue Latitude  \
# Neighbourhood
# City Center, Passeig de Gracia                        100             100
# Ciutat Vella, La Barcelonata                          100             100
# Diagonal                                              100             100
# El Baix Guinardo, El Camp D'En Grassot I Gracia...    100             100
# El Besos I El Maresme, Paolo Alto Market               57              57
#
#                                                     Venue Longitude  \
# Neighbourhood
# City Center, Passeig de Gracia                                  100
# Ciutat Vella, La Barcelonata                                    100
# Diagonal                                                        100
# El Baix Guinardo, El Camp D'En Grassot I Gracia...              100
# El Besos I El Maresme, Paolo Alto Market                         57
#
#                                                     Venue category   Id
# Neighbourhood
# City Center, Passeig de Gracia                                 100  100
# Ciutat Vella, La Barcelonata                                   100  100
# Diagonal                                                       100  100
# El Baix Guinardo, El Camp D'En Grassot I Gracia...             100  100
# El Besos I El Maresme, Paolo Alto Market                        57   57

# %% [markdown]
# Next we get the results for the number of ratings for each venue ( which will give us the faint idea of most visited places ) and the cost ( whether expensive or cheap )

# %%
# lets get those data of expense and number of ratings
#results = []
#for idt in barcelona_venues['Id']:
#    url='https://api.foursquare.com/v2/venues/'+idt+'?&client_id={}&client_secret={}&v={}&ll={},{}'.format(
#        CLIENT_ID,
#        CLIENT_SECRET,
#        API_VERSION,
#        neighborhood_lat,
#        neighborhood_lng)
#    try:
#        results.append(requests.get(url).json()["response"]['venue']['attributes']['groups'][0]['items'][0]['priceTier'])
#    except:
#        results.append('Na')

# %%
#analysing neighborhoods
barcelona_onehot = pd.get_dummies(barcelona_venues[['Venue category']], prefix = '', prefix_sep='')
barcelona_onehot['Neighbourhood']=barcelona_venues['Neighbourhood']
fixed_columns = [barcelona_onehot.columns[-1]]+list(barcelona_onehot.columns[:-1])
barcelona_onehot= barcelona_onehot[fixed_columns]
barcelona_onehot.shape
#grouping by neighbourhood
barcelona_grouped=barcelona_onehot.groupby('Neighbourhood').mean().reset_index()
barcelona_grouped
# Out:
#                                         Neighbourhood  Accessories Store  \
# 0                      City Center, Passeig de Gracia               0.00
# 1                        Ciutat Vella, La Barcelonata               0.00
# 2                                            Diagonal               0.00
# 3   El Baix Guinardo, El Camp D'En Grassot I Graci...               0.00
# 4            El Besos I El Maresme, Paolo Alto Market               0.00
# 5                          El Camp de L'Arpa del Clot               0.00
# 6              El Carmel, Horta, La Font D'En Fargues               0.00
# 7                                         El Guinardo               0.00
# 8                                        El Poble Nou               0.00
# 9                                        El Poble Sec               0.00
# 10                                           El Raval               0.00
# 11                        Fort Pienc, Sagrada Familia               0.01
# 12    Girona, Jardins de Jaume Perich, Carrer d'Arago               0.01
# 13                                     Gothic Quarter               0.00
# 14                         Gracia, Can Baro, Alfons X               0.00
# 15      Horta, Sant Genis Dels Agudells, La Teixonera               0.00
# 16                           Hospital Clinic, La Fira               0.00
# 17            La Nova Esquerra de L'Exiample, Entenca               0.00
# 18                                         La Sagrega               0.00
# 19  La Trinitat Nova, Trinitat Vella, Torre Baro, ...               0.00
# 20      La Verneda I La Pau, Sant Marti de Provencals               0.00
# 21  Les Corts, La Maternitat I Sant Ramon, Sants-M...               0.00
# 22                                       Les Roquetes               0.00
# 23  Parc de Montjuic, La Marina de Port, La Marina...               0.00
# 24                                  Port de Barcelona               0.00
# 25                 Porta,Virrei Amat, La prosperitat                0.00
# 26                          Sant Adreu, Baro de Viver               0.00
# 27                              Sant Antoni, Rocafort               0.00
# 28                       Sant Gervasi, Hospital Plato               0.00
# 29       Sant Gervasi-Galvany, La Bonanova, Turo Parc               0.01
# 30  Sant Gervasi-La Bonanova, Av. Tibidabo,  El Pu...               0.00
# 31     Sant Marti, La Verneda, Glories, Arc de Triomf               0.00
# 32                  Sants, Taragona, Placa del Centre               0.00
# 33             Saria, Pedralbes, Ciutat Universitaria               0.00
# 34                   Urgell,Jardin de Cesar Martinell               0.00
# 35  Vallcarca I Els Penitents, El parc del Turo de...               0.00
# 36                                        Vallvidrera               0.00
# 37                    Verdaguer, Passeig de Sant Joan               0.01
# 38                                     Vila de Gracia               0.00
# 39       Vilapicina, Can Peguera, El Turo de La Peira               0.00
# 40                                        Zona Franca               0.00
# 41                        placa de Tetuan, Urquinaona               0.02
#
#     African Restaurant  American Restaurant  Antique Shop  Arcade  \
# 0                 0.00             0.000000          0.00    0.00
# 1                 0.00             0.000000          0.00    0.00
# 2                 0.00             0.000000          0.00    0.00
# 3                 0.00             0.000000          0.00    0.00
# 4                 0.00             0.017544          0.00    0.00
# 5                 0.00             0.000000          0.00    0.00
# 6                 0.00             0.000000          0.00    0.00
# 7                 0.00             0.000000          0.00    0.00
# 8                 0.00             0.000000          0.00    0.00
# 9                 0.00             0.000000          0.00    0.00
# 10                0.00             0.000000          0.00    0.00
# 11                0.00             0.000000          0.00    0.01
# 12                0.00             0.000000          0.00    0.00
# 13                0.00             0.000000          0.00    0.00
# 14                0.00             0.000000          0.00    0.00
# 15                0.00             0.000000          0.00    0.00
# 16                0.00             0.000000          0.00    0.00
# 17                0.00             0.000000          0.00    0.00
# 18                0.00             0.000000          0.00    0.00
# 19                0.00             0.000000          0.00    0.00
# 20                0.00             0.000000          0.00    0.00
# 21                0.00             0.000000          0.00    0.00
# 22                0.00             0.000000          0.00    0.00
# 23                0.00             0.000000          0.00    0.00
# 24                0.00             0.000000          0.00    0.00
# 25                0.00             0.000000          0.00    0.00
# 26                0.00             0.025641          0.00    0.00
# 27                0.00             0.000000          0.00    0.00
# 28                0.00             0.000000          0.00    0.00
# 29                0.01             0.010000          0.00    0.00
# 30                0.00             0.000000          0.00    0.00
# 31                0.00             0.000000          0.01    0.00
# 32                0.01             0.000000          0.00    0.00
# 33                0.00             0.000000          0.00    0.00
# 34                0.00             0.000000          0.00    0.00
# 35                0.00             0.000000          0.00    0.00
# 36                0.00             0.000000          0.00    0.00
# 37                0.00             0.000000          0.00    0.00
# 38                0.00             0.000000          0.00    0.00
# 39                0.00             0.000000          0.00    0.00
# 40                0.00             0.000000          0.00    0.00
# 41                0.00             0.000000          0.00    0.00
#
#     Arepa Restaurant  Argentinian Restaurant  Art Gallery  Art Museum  \
# 0               0.00                0.000000     0.010000        0.00
# 1               0.01                0.000000     0.020000        0.02
# 2               0.00                0.000000     0.020000        0.00
# 3               0.01                0.000000     0.000000        0.00
# 4               0.00                0.000000     0.000000        0.00
# 5               0.00                0.010000     0.000000        0.00
# 6               0.00                0.000000     0.000000        0.00
# 7               0.00                0.017857     0.000000        0.00
# 8               0.00                0.000000     0.000000        0.00
# 9               0.00                0.000000     0.000000        0.00
# 10              0.00                0.000000     0.000000        0.01
# 11              0.00                0.000000     0.020000        0.00
# 12              0.00                0.000000     0.010000        0.00
# 13              0.00                0.000000     0.000000        0.00
# 14              0.01                0.000000     0.000000        0.02
# 15              0.00                0.000000     0.000000        0.00
# 16              0.00                0.020000     0.020000        0.00
# 17              0.00                0.000000     0.000000        0.00
# 18              0.01                0.000000     0.000000        0.02
# 19              0.00                0.000000     0.000000        0.00
# 20              0.01                0.000000     0.000000        0.02
# 21              0.00                0.000000     0.000000        0.00
# 22              0.01                0.000000     0.000000        0.02
# 23              0.00                0.018182     0.000000        0.00
# 24              0.00                0.000000     0.000000        0.00
# 25              0.00                0.000000     0.000000        0.02
# 26              0.00                0.000000     0.000000        0.00
# 27              0.00                0.020000     0.000000        0.00
# 28              0.00                0.000000     0.010000        0.00
# 29              0.00                0.010000     0.000000        0.00
# 30              0.00                0.020833     0.010417        0.00
# 31              0.00                0.010000     0.030000        0.02
# 32              0.00                0.000000     0.000000        0.00
# 33              0.00                0.000000     0.000000        0.00
# 34              0.00                0.020000     0.000000        0.00
# 35              0.00                0.027027     0.000000        0.00
# 36              0.00                0.000000     0.000000        0.00
# 37              0.00                0.010000     0.010000        0.00
# 38              0.00                0.000000     0.000000        0.02
# 39              0.01                0.000000     0.000000        0.02
# 40              0.00                0.000000     0.000000        0.00
# 41              0.00                0.000000     0.020000        0.00
#
#        ...       Turkish Restaurant  Vacation Rental  \
# 0      ...                 0.000000             0.00
# 1      ...                 0.000000             0.00
# 2      ...                 0.000000             0.00
# 3      ...                 0.000000             0.00
# 4      ...                 0.017544             0.00
# 5      ...                 0.000000             0.00
# 6      ...                 0.000000             0.00
# 7      ...                 0.017857             0.00
# 8      ...                 0.000000             0.00
# 9      ...                 0.000000             0.00
# 10     ...                 0.000000             0.00
# 11     ...                 0.000000             0.00
# 12     ...                 0.000000             0.00
# 13     ...                 0.000000             0.00
# 14     ...                 0.000000             0.00
# 15     ...                 0.000000             0.00
# 16     ...                 0.000000             0.00
# 17     ...                 0.000000             0.00
# 18     ...                 0.000000             0.00
# 19     ...                 0.000000             0.00
# 20     ...                 0.000000             0.00
# 21     ...                 0.010309             0.00
# 22     ...                 0.000000             0.00
# 23     ...                 0.000000             0.00
# 24     ...                 0.000000             0.00
# 25     ...                 0.000000             0.00
# 26     ...                 0.000000             0.00
# 27     ...                 0.000000             0.00
# 28     ...                 0.000000             0.00
# 29     ...                 0.000000             0.00
# 30     ...                 0.000000             0.00
# 31     ...                 0.000000             0.00
# 32     ...                 0.000000             0.01
# 33     ...                 0.000000             0.00
# 34     ...                 0.000000             0.00
# 35     ...                 0.000000             0.00
# 36     ...                 0.000000             0.00
# 37     ...                 0.000000             0.00
# 38     ...                 0.000000             0.00
# 39     ...                 0.000000             0.00
# 40     ...                 0.000000             0.00
# 41     ...                 0.000000             0.00
#
#     Vegetarian / Vegan Restaurant  Venezuelan Restaurant  Video Store  \
# 0                        0.000000                   0.00     0.000000
# 1                        0.030000                   0.00     0.000000
# 2                        0.010000                   0.00     0.000000
# 3                        0.010000                   0.00     0.000000
# 4                        0.000000                   0.00     0.000000
# 5                        0.010000                   0.00     0.000000
# 6                        0.028571                   0.00     0.000000
# 7                        0.000000                   0.00     0.000000
# 8                        0.018519                   0.00     0.000000
# 9                        0.010000                   0.00     0.000000
# 10                       0.040000                   0.00     0.000000
# 11                       0.020000                   0.00     0.000000
# 12                       0.000000                   0.00     0.000000
# 13                       0.010000                   0.00     0.000000
# 14                       0.020000                   0.00     0.000000
# 15                       0.000000                   0.00     0.000000
# 16                       0.010000                   0.00     0.010000
# 17                       0.000000                   0.00     0.000000
# 18                       0.020000                   0.00     0.000000
# 19                       0.010000                   0.00     0.000000
# 20                       0.020000                   0.00     0.000000
# 21                       0.000000                   0.00     0.000000
# 22                       0.020000                   0.00     0.000000
# 23                       0.000000                   0.00     0.000000
# 24                       0.000000                   0.00     0.000000
# 25                       0.030000                   0.00     0.000000
# 26                       0.000000                   0.00     0.000000
# 27                       0.020000                   0.01     0.000000
# 28                       0.010000                   0.00     0.000000
# 29                       0.000000                   0.00     0.000000
# 30                       0.000000                   0.00     0.000000
# 31                       0.010000                   0.00     0.000000
# 32                       0.010000                   0.00     0.000000
# 33                       0.000000                   0.00     0.000000
# 34                       0.020000                   0.01     0.000000
# 35                       0.000000                   0.00     0.027027
# 36                       0.000000                   0.00     0.000000
# 37                       0.000000                   0.00     0.000000
# 38                       0.030000                   0.00     0.000000
# 39                       0.020000                   0.00     0.000000
# 40                       0.000000                   0.00     0.000000
# 41                       0.020000                   0.00     0.000000
#
#     Vietnamese Restaurant  Wine Bar  Wine Shop  Women's Store  Yoga Studio
# 0                    0.00  0.010000   0.000000       0.030000         0.00
# 1                    0.00  0.040000   0.010000       0.000000         0.00
# 2                    0.00  0.010000   0.000000       0.020000         0.00
# 3                    0.00  0.020000   0.000000       0.000000         0.01
# 4                    0.00  0.000000   0.000000       0.000000         0.00
# 5                    0.00  0.000000   0.000000       0.000000         0.01
# 6                    0.00  0.000000   0.000000       0.000000         0.00
# 7                    0.00  0.017857   0.000000       0.000000         0.00
# 8                    0.00  0.000000   0.000000       0.000000         0.00
# 9                    0.00  0.020000   0.010000       0.000000         0.00
# 10                   0.01  0.010000   0.000000       0.000000         0.00
# 11                   0.00  0.000000   0.010000       0.000000         0.02
# 12                   0.00  0.010000   0.000000       0.030000         0.00
# 13                   0.01  0.010000   0.000000       0.010000         0.00
# 14                   0.00  0.060000   0.010000       0.000000         0.00
# 15                   0.00  0.000000   0.000000       0.000000         0.00
# 16                   0.00  0.000000   0.000000       0.000000         0.00
# 17                   0.00  0.000000   0.000000       0.000000         0.00
# 18                   0.00  0.060000   0.010000       0.000000         0.00
# 19                   0.00  0.030000   0.010000       0.000000         0.01
# 20                   0.00  0.060000   0.010000       0.000000         0.00
# 21                   0.00  0.000000   0.010309       0.000000         0.00
# 22                   0.00  0.060000   0.010000       0.000000         0.00
# 23                   0.00  0.018182   0.000000       0.000000         0.00
# 24                   0.00  0.000000   0.000000       0.000000         0.00
# 25                   0.01  0.020000   0.010000       0.000000         0.00
# 26                   0.00  0.000000   0.000000       0.038462         0.00
# 27                   0.00  0.020000   0.000000       0.000000         0.00
# 28                   0.00  0.020000   0.010000       0.000000         0.00
# 29                   0.00  0.010000   0.000000       0.000000         0.00
# 30                   0.00  0.031250   0.000000       0.000000         0.00
# 31                   0.00  0.010000   0.000000       0.000000         0.00
# 32                   0.00  0.000000   0.000000       0.000000         0.00
# 33                   0.00  0.000000   0.030000       0.000000         0.00
# 34                   0.00  0.010000   0.000000       0.000000         0.00
# 35                   0.00  0.054054   0.000000       0.000000         0.00
# 36                   0.00  0.000000   0.000000       0.000000         0.00
# 37                   0.00  0.000000   0.000000       0.000000         0.01
# 38                   0.01  0.020000   0.010000       0.000000         0.00
# 39                   0.00  0.060000   0.010000       0.000000         0.00
# 40                   0.00  0.000000   0.000000       0.000000         0.00
# 41                   0.00  0.000000   0.000000       0.010000         0.01
#
# [42 rows x 248 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories=row.iloc[1:]
    row_categories_sorted=row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#printing most common venues
num_top_venues=10
for hood in barcelona_grouped['Neighbourhood']:
    print('____'+hood+'____')
    temp=barcelona_grouped[barcelona_grouped['Neighbourhood']==hood].T.reset_index()
    temp.columns=['venue','freq']
    temp=temp.iloc[1:]
    temp['freq']=temp['freq'].astype(float)
    temp=temp.round({'freq':2})
    print(temp.sort_values('freq',ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
#sorting in descending order
num_top_venues=10
indicators=['st','nd','rd']
columns=['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append("{}{} Most Common Venue".format(ind+1,indicators[ind]))
    except:
        columns.append("{}th Most Common Venue".format(ind+1))
#new dataframe
neighbourhoods_venuessorted = pd.DataFrame(columns=columns)
neighbourhoods_venuessorted['Neighbourhood']=barcelona_grouped['Neighbourhood']
for ind in np.arange(barcelona_grouped.shape[0]):
    neighbourhoods_venuessorted.iloc[ind,1:] = return_most_common_venues(barcelona_grouped.iloc[ind, :], num_top_venues)
neighbourhoods_venuessorted
# Out:
# ____City Center, Passeig de Gracia____
#                       venue  freq
# 0                     Hotel  0.16
# 1            Clothing Store  0.06
# 2  Mediterranean Restaurant  0.05
# 3                Restaurant  0.04
# 4                    Hostel  0.04
# 5          Tapas Restaurant  0.04
# 6       Sporting Goods Shop  0.03
# 7             Women's Store  0.03
# 8              Cocktail Bar  0.03
# 9        Spanish Restaurant  0.03
#
#
# ____Ciutat Vella, La Barcelonata____
#                 venue  freq
# 0    Tapas Restaurant  0.11
# 1                 Bar  0.07
# 2        Cocktail Bar  0.06
# 3            Wine Bar  0.04
# 4  Italian Restaurant  0.04
# 5               Hotel  0.03
# 6                Café  0.03
# 7  Spanish Restaurant  0.03
# 8         Coffee Shop  0.03
# 9         Pizza Place  0.03
#
#
# ____Diagonal____
#                       venue  freq
# 0                     Hotel  0.18
# 1                  Boutique  0.10
# 2  Mediterranean Restaurant  0.06
# 3        Spanish Restaurant  0.05
# 4          Tapas Restaurant  0.04
# 5       Japanese Restaurant  0.04
# 6                    Hostel  0.03
# 7             Women's Store  0.02
# 8                Restaurant  0.02
# 9    Furniture / Home Store  0.02
#
#
# ____El Baix Guinardo, El Camp D'En Grassot I Gracia  Nova____
#                        venue  freq
# 0         Italian Restaurant  0.06
# 1                 Restaurant  0.06
# 2                Coffee Shop  0.05
# 3                      Hotel  0.04
# 4                      Plaza  0.04
# 5               Burger Joint  0.04
# 6                       Café  0.03
# 7             Sandwich Place  0.03
# 8  Latin American Restaurant  0.03
# 9              Deli / Bodega  0.03
#
#
# ____El Besos I El Maresme, Paolo Alto Market____
#                       venue  freq
# 0  Mediterranean Restaurant  0.16
# 1               Pizza Place  0.07
# 2                Restaurant  0.07
# 3        Spanish Restaurant  0.05
# 4        Italian Restaurant  0.05
# 5                    Bakery  0.04
# 6         Food & Drink Shop  0.04
# 7                      Café  0.04
# 8                       Bar  0.04
# 9         Indian Restaurant  0.04
#
#
# ____El Camp de L'Arpa del Clot____
#                 venue  freq
# 0                Café  0.08
# 1               Hotel  0.06
# 2  Spanish Restaurant  0.05
# 3          Restaurant  0.05
# 4       Grocery Store  0.04
# 5                 Bar  0.03
# 6    Tapas Restaurant  0.03
# 7      Breakfast Spot  0.03
# 8               Plaza  0.03
# 9  Mexican Restaurant  0.03
#
#
# ____El Carmel, Horta, La Font D'En Fargues____
#                       venue  freq
# 0        Spanish Restaurant  0.09
# 1                     Hotel  0.06
# 2            Soccer Stadium  0.06
# 3       Sporting Goods Shop  0.06
# 4  Mediterranean Restaurant  0.06
# 5                      Café  0.03
# 6                      Park  0.03
# 7              Cocktail Bar  0.03
# 8        Basketball Stadium  0.03
# 9         College Cafeteria  0.03
#
#
# ____El Guinardo____
#                       venue  freq
# 0                    Bakery  0.11
# 1                Restaurant  0.09
# 2                     Hotel  0.09
# 3        Italian Restaurant  0.05
# 4        Spanish Restaurant  0.04
# 5               Pizza Place  0.04
# 6                 Gastropub  0.04
# 7  Mediterranean Restaurant  0.04
# 8             Grocery Store  0.04
# 9               Supermarket  0.04
#
#
# ____El Poble Nou____
#                 venue  freq
# 0  Spanish Restaurant  0.07
# 1              Hostel  0.06
# 2         Music Venue  0.04
# 3         Coffee Shop  0.04
# 4    Tapas Restaurant  0.04
# 5         Supermarket  0.04
# 6              Bistro  0.04
# 7        Burger Joint  0.04
# 8               Hotel  0.04
# 9                Café  0.04
#
#
# ____El Poble Sec____
#                       venue  freq
# 0          Tapas Restaurant  0.15
# 1              Cocktail Bar  0.07
# 2                       Bar  0.06
# 3        Spanish Restaurant  0.05
# 4                   Theater  0.05
# 5  Mediterranean Restaurant  0.04
# 6                      Café  0.04
# 7                Restaurant  0.04
# 8                     Hotel  0.04
# 9                  Beer Bar  0.03
#
#
# ____El Raval____
#                            venue  freq
# 0                          Hotel  0.06
# 1               Tapas Restaurant  0.06
# 2                   Cocktail Bar  0.05
# 3                            Bar  0.05
# 4             Spanish Restaurant  0.05
# 5                    Coffee Shop  0.04
# 6  Vegetarian / Vegan Restaurant  0.04
# 7                      Bookstore  0.04
# 8             Italian Restaurant  0.03
# 9                     Restaurant  0.03
#
#
# ____Fort Pienc, Sagrada Familia____
#                 venue  freq
# 0               Hotel  0.13
# 1                Café  0.06
# 2         Coffee Shop  0.05
# 3    Tapas Restaurant  0.05
# 4              Hostel  0.04
# 5              Bistro  0.03
# 6  Italian Restaurant  0.03
# 7                 Gym  0.03
# 8  Chinese Restaurant  0.03
# 9         Yoga Studio  0.02
#
#
# ____Girona, Jardins de Jaume Perich, Carrer d'Arago____
#                       venue  freq
# 0                     Hotel  0.13
# 1            Clothing Store  0.07
# 2                 Bookstore  0.05
# 3          Tapas Restaurant  0.04
# 4                Restaurant  0.04
# 5  Mediterranean Restaurant  0.04
# 6             Women's Store  0.03
# 7                    Bakery  0.03
# 8              Cocktail Bar  0.03
# 9        Seafood Restaurant  0.03
#
#
# ____Gothic Quarter____
#                  venue  freq
# 0                Plaza  0.09
# 1                Hotel  0.08
# 2     Tapas Restaurant  0.07
# 3       Ice Cream Shop  0.06
# 4   Spanish Restaurant  0.05
# 5                 Café  0.04
# 6         Dessert Shop  0.04
# 7            Gift Shop  0.03
# 8  Japanese Restaurant  0.03
# 9          Coffee Shop  0.03
#
#
# ____Gracia, Can Baro, Alfons X____
#                       venue  freq
# 0          Tapas Restaurant  0.13
# 1              Cocktail Bar  0.09
# 2                  Wine Bar  0.06
# 3                       Bar  0.05
# 4  Mediterranean Restaurant  0.04
# 5                     Hotel  0.03
# 6              Dessert Shop  0.03
# 7        Seafood Restaurant  0.03
# 8        Spanish Restaurant  0.03
# 9               Coffee Shop  0.03
#
#
# ____Horta, Sant Genis Dels Agudells, La Teixonera____
#                            venue  freq
# 0                 Scenic Lookout  0.50
# 1                 Breakfast Spot  0.25
# 2                    Supermarket  0.25
# 3                Organic Grocery  0.00
# 4                    Pastry Shop  0.00
# 5                           Park  0.00
# 6  Paper / Office Supplies Store  0.00
# 7              Paella Restaurant  0.00
# 8              Outdoor Sculpture  0.00
# 9              Accessories Store  0.00
#
#
# ____Hospital Clinic, La Fira____
#                       venue  freq
# 0              Cocktail Bar  0.10
# 1        Spanish Restaurant  0.07
# 2                     Hotel  0.07
# 3                Restaurant  0.06
# 4  Mediterranean Restaurant  0.05
# 5       Japanese Restaurant  0.05
# 6          Tapas Restaurant  0.04
# 7                    Bakery  0.03
# 8            Sandwich Place  0.03
# 9                    Hostel  0.02
#
#
# ____La Nova Esquerra de L'Exiample, Entenca____
#                       venue  freq
# 0       Japanese Restaurant  0.12
# 1            Breakfast Spot  0.06
# 2                      Café  0.06
# 3  Mediterranean Restaurant  0.06
# 4                    Bakery  0.04
# 5        Italian Restaurant  0.04
# 6               Pizza Place  0.04
# 7        Mexican Restaurant  0.04
# 8              Burger Joint  0.04
# 9         Indian Restaurant  0.04
#
#
# ____La Sagrega____
#                       venue  freq
# 0          Tapas Restaurant  0.13
# 1              Cocktail Bar  0.09
# 2                  Wine Bar  0.06
# 3                       Bar  0.05
# 4  Mediterranean Restaurant  0.04
# 5                     Hotel  0.03
# 6              Dessert Shop  0.03
# 7        Seafood Restaurant  0.03
# 8        Spanish Restaurant  0.03
# 9               Coffee Shop  0.03
#
#
# ____La Trinitat Nova, Trinitat Vella, Torre Baro, Vallbona____
#                       venue  freq
# 0          Tapas Restaurant  0.13
# 1              Cocktail Bar  0.08
# 2                       Bar  0.05
# 3        Spanish Restaurant  0.05
# 4                     Hotel  0.05
# 5  Mediterranean Restaurant  0.05
# 6                Restaurant  0.04
# 7                   Theater  0.04
# 8                      Café  0.03
# 9                  Wine Bar  0.03
#
#
# ____La Verneda I La Pau, Sant Marti de Provencals____
#                       venue  freq
# 0          Tapas Restaurant  0.13
# 1              Cocktail Bar  0.09
# 2                  Wine Bar  0.06
# 3                       Bar  0.05
# 4  Mediterranean Restaurant  0.04
# 5                     Hotel  0.03
# 6              Dessert Shop  0.03
# 7        Seafood Restaurant  0.03
# 8        Spanish Restaurant  0.03
# 9               Coffee Shop  0.03
#
#
# ____Les Corts, La Maternitat I Sant Ramon, Sants-Montjuic____
#                       venue  freq
# 0                    Bakery  0.09
# 1        Spanish Restaurant  0.09
# 2               Pizza Place  0.06
# 3                Restaurant  0.06
# 4             Grocery Store  0.05
# 5                      Café  0.04
# 6          Tapas Restaurant  0.03
# 7               Supermarket  0.03
# 8  Mediterranean Restaurant  0.03
# 9                     Plaza  0.02
#
#
# ____Les Roquetes____
#                       venue  freq
# 0          Tapas Restaurant  0.13
# 1              Cocktail Bar  0.09
# 2                  Wine Bar  0.06
# 3                       Bar  0.05
# 4  Mediterranean Restaurant  0.04
# 5                     Hotel  0.03
# 6              Dessert Shop  0.03
# 7        Seafood Restaurant  0.03
# 8        Spanish Restaurant  0.03
# 9               Coffee Shop  0.03
#
#
# ____Parc de Montjuic, La Marina de Port, La Marina del Prat Vermell____
#                 venue  freq
# 0                Park  0.09
# 1    Tapas Restaurant  0.09
# 2               Hotel  0.09
# 3              Hostel  0.07
# 4           Nightclub  0.05
# 5         Pizza Place  0.04
# 6  Spanish Restaurant  0.04
# 7      Scenic Lookout  0.04
# 8        Cocktail Bar  0.04
# 9         Karaoke Bar  0.02
#
#
# ____Port de Barcelona____
#                 venue  freq
# 0              Hostel  0.17
# 1               Hotel  0.06
# 2    Tapas Restaurant  0.06
# 3         Coffee Shop  0.06
# 4  Seafood Restaurant  0.06
# 5                Park  0.06
# 6       Shopping Mall  0.06
# 7                 Bar  0.06
# 8      History Museum  0.06
# 9      Lingerie Store  0.06
#
#
# ____Porta,Virrei Amat, La prosperitat ____
#                 venue  freq
# 0    Tapas Restaurant  0.08
# 1  Spanish Restaurant  0.07
# 2               Hotel  0.06
# 3               Plaza  0.06
# 4                 Bar  0.04
# 5                Café  0.04
# 6         Coffee Shop  0.04
# 7        Cocktail Bar  0.03
# 8          Restaurant  0.03
# 9        Dessert Shop  0.03
#
#
# ____Sant Adreu, Baro de Viver____
#                   venue  freq
# 0        Clothing Store  0.10
# 1        Sandwich Place  0.05
# 2    Spanish Restaurant  0.05
# 3          Burger Joint  0.05
# 4         Women's Store  0.04
# 5     Electronics Store  0.04
# 6  Fast Food Restaurant  0.04
# 7              Boutique  0.03
# 8   Japanese Restaurant  0.03
# 9        Cosmetics Shop  0.03
#
#
# ____Sant Antoni, Rocafort____
#                       venue  freq
# 0                     Hotel  0.08
# 1                      Café  0.06
# 2                       Bar  0.05
# 3              Cocktail Bar  0.05
# 4                Restaurant  0.04
# 5  Mediterranean Restaurant  0.03
# 6            Breakfast Spot  0.03
# 7          Tapas Restaurant  0.03
# 8               Coffee Shop  0.03
# 9               Pizza Place  0.03
#
#
# ____Sant Gervasi, Hospital Plato____
#                       venue  freq
# 0                Restaurant  0.08
# 1       Japanese Restaurant  0.05
# 2              Cocktail Bar  0.05
# 3          Tapas Restaurant  0.05
# 4    Furniture / Home Store  0.05
# 5  Mediterranean Restaurant  0.05
# 6                      Café  0.04
# 7            Ice Cream Shop  0.04
# 8                     Hotel  0.04
# 9        Spanish Restaurant  0.04
#
#
# ____Sant Gervasi-Galvany, La Bonanova, Turo Parc____
#                       venue  freq
# 0        Spanish Restaurant  0.09
# 1  Mediterranean Restaurant  0.07
# 2                Restaurant  0.06
# 3                     Hotel  0.05
# 4                    Bakery  0.04
# 5       Japanese Restaurant  0.04
# 6                      Café  0.03
# 7               Pizza Place  0.03
# 8          Tapas Restaurant  0.03
# 9              Cocktail Bar  0.03
#
#
# ____Sant Gervasi-La Bonanova, Av. Tibidabo,  El Putxet____
#                       venue  freq
# 0  Mediterranean Restaurant  0.07
# 1             Grocery Store  0.05
# 2                     Hotel  0.05
# 3                Restaurant  0.05
# 4       Japanese Restaurant  0.05
# 5                    Bakery  0.04
# 6               Pizza Place  0.04
# 7                      Café  0.03
# 8        Spanish Restaurant  0.03
# 9              Cocktail Bar  0.03
#
#
# ____Sant Marti, La Verneda, Glories, Arc de Triomf____
#                       venue  freq
# 0                     Hotel  0.07
# 1                       Bar  0.07
# 2  Mediterranean Restaurant  0.06
# 3        Spanish Restaurant  0.05
# 4            Breakfast Spot  0.04
# 5        Italian Restaurant  0.04
# 6                      Café  0.04
# 7                    Bakery  0.03
# 8          Tapas Restaurant  0.03
# 9               Music Venue  0.03
#
#
# ____Sants, Taragona, Placa del Centre____
#                       venue  freq
# 0                     Hotel  0.11
# 1                Restaurant  0.10
# 2  Mediterranean Restaurant  0.06
# 3               Coffee Shop  0.04
# 4       Japanese Restaurant  0.04
# 5                       Bar  0.03
# 6                    Bakery  0.03
# 7                      Park  0.03
# 8        Italian Restaurant  0.03
# 9                      Café  0.03
#
#
# ____Saria, Pedralbes, Ciutat Universitaria____
#                  venue  freq
# 0           Restaurant  0.09
# 1  Japanese Restaurant  0.06
# 2          Coffee Shop  0.05
# 3       Sandwich Place  0.04
# 4   Spanish Restaurant  0.04
# 5                 Café  0.04
# 6         Cocktail Bar  0.03
# 7                 Park  0.03
# 8                Hotel  0.03
# 9  Sporting Goods Shop  0.03
#
#
# ____Urgell,Jardin de Cesar Martinell____
#                       venue  freq
# 0          Tapas Restaurant  0.07
# 1                      Café  0.06
# 2                     Hotel  0.06
# 3              Cocktail Bar  0.06
# 4                       Bar  0.04
# 5  Mediterranean Restaurant  0.04
# 6               Coffee Shop  0.03
# 7              Dessert Shop  0.03
# 8                   Gay Bar  0.03
# 9                    Hostel  0.02
#
#
# ____Vallcarca I Els Penitents, El parc del Turo del Putxet, El Coll____
#                 venue  freq
# 0              Bakery  0.14
# 1                Café  0.11
# 2        Burger Joint  0.11
# 3  Italian Restaurant  0.08
# 4            Wine Bar  0.05
# 5    Tapas Restaurant  0.05
# 6         Supermarket  0.05
# 7      Breakfast Spot  0.05
# 8                 Gym  0.03
# 9    Sushi Restaurant  0.03
#
#
# ____Vallvidrera____
#                       venue  freq
# 0  Mediterranean Restaurant  0.13
# 1                     Hotel  0.11
# 2        Spanish Restaurant  0.07
# 3                    Bakery  0.07
# 4                      Café  0.07
# 5                     Diner  0.07
# 6             Train Station  0.04
# 7              Burger Joint  0.04
# 8            Breakfast Spot  0.02
# 9                       Gym  0.02
#
#
# ____Verdaguer, Passeig de Sant Joan____
#                venue  freq
# 0              Hotel  0.17
# 1               Café  0.08
# 2             Hostel  0.08
# 3         Restaurant  0.06
# 4        Coffee Shop  0.05
# 5   Tapas Restaurant  0.03
# 6     Breakfast Spot  0.03
# 7  Indian Restaurant  0.03
# 8        Pizza Place  0.03
# 9       Burger Joint  0.03
#
#
# ____Vila de Gracia____
#                 venue  freq
# 0    Tapas Restaurant  0.08
# 1  Spanish Restaurant  0.07
# 2               Hotel  0.06
# 3               Plaza  0.06
# 4                 Bar  0.04
# 5                Café  0.04
# 6         Coffee Shop  0.04
# 7        Cocktail Bar  0.03
# 8          Restaurant  0.03
# 9        Dessert Shop  0.03
#
#
# ____Vilapicina, Can Peguera, El Turo de La Peira____
#                       venue  freq
# 0          Tapas Restaurant  0.13
# 1              Cocktail Bar  0.09
# 2                  Wine Bar  0.06
# 3                       Bar  0.05
# 4  Mediterranean Restaurant  0.04
# 5                     Hotel  0.03
# 6              Dessert Shop  0.03
# 7        Seafood Restaurant  0.03
# 8        Spanish Restaurant  0.03
# 9               Coffee Shop  0.03
#
#
# ____Zona Franca____
#                       venue  freq
# 0                Restaurant   0.3
# 1  Mediterranean Restaurant   0.2
# 2              Tennis Court   0.1
# 3                      Park   0.1
# 4                     Hotel   0.1
# 5                    Market   0.1
# 6           Coworking Space   0.1
# 7              Optical Shop   0.0
# 8               Opera House   0.0
# 9           Organic Grocery   0.0
#
#
# ____placa de Tetuan, Urquinaona____
#                 venue  freq
# 0               Hotel  0.23
# 1                Café  0.07
# 2         Coffee Shop  0.04
# 3              Hostel  0.04
# 4          Restaurant  0.04
# 5     Bed & Breakfast  0.03
# 6    Tapas Restaurant  0.03
# 7  Spanish Restaurant  0.03
# 8      Ice Cream Shop  0.02
# 9           Bookstore  0.02
#                                         Neighbourhood  \
# 0                      City Center, Passeig de Gracia
# 1                        Ciutat Vella, La Barcelonata
# 2                                            Diagonal
# 3   El Baix Guinardo, El Camp D'En Grassot I Graci...
# 4            El Besos I El Maresme, Paolo Alto Market
# 5                          El Camp de L'Arpa del Clot
# 6              El Carmel, Horta, La Font D'En Fargues
# 7                                         El Guinardo
# 8                                        El Poble Nou
# 9                                        El Poble Sec
# 10                                           El Raval
# 11                        Fort Pienc, Sagrada Familia
# 12    Girona, Jardins de Jaume Perich, Carrer d'Arago
# 13                                     Gothic Quarter
# 14                         Gracia, Can Baro, Alfons X
# 15      Horta, Sant Genis Dels Agudells, La Teixonera
# 16                           Hospital Clinic, La Fira
# 17            La Nova Esquerra de L'Exiample, Entenca
# 18                                         La Sagrega
# 19  La Trinitat Nova, Trinitat Vella, Torre Baro, ...
# 20      La Verneda I La Pau, Sant Marti de Provencals
# 21  Les Corts, La Maternitat I Sant Ramon, Sants-M...
# 22                                       Les Roquetes
# 23  Parc de Montjuic, La Marina de Port, La Marina...
# 24                                  Port de Barcelona
# 25                 Porta,Virrei Amat, La prosperitat
# 26                          Sant Adreu, Baro de Viver
# 27                              Sant Antoni, Rocafort
# 28                       Sant Gervasi, Hospital Plato
# 29       Sant Gervasi-Galvany, La Bonanova, Turo Parc
# 30  Sant Gervasi-La Bonanova, Av. Tibidabo,  El Pu...
# 31     Sant Marti, La Verneda, Glories, Arc de Triomf
# 32                  Sants, Taragona, Placa del Centre
# 33             Saria, Pedralbes, Ciutat Universitaria
# 34                   Urgell,Jardin de Cesar Martinell
# 35  Vallcarca I Els Penitents, El parc del Turo de...
# 36                                        Vallvidrera
# 37                    Verdaguer, Passeig de Sant Joan
# 38                                     Vila de Gracia
# 39       Vilapicina, Can Peguera, El Turo de La Peira
# 40                                        Zona Franca
# 41                        placa de Tetuan, Urquinaona
#
#        1st Most Common Venue     2nd Most Common Venue  \
# 0                      Hotel            Clothing Store
# 1           Tapas Restaurant                       Bar
# 2                      Hotel                  Boutique
# 3         Italian Restaurant                Restaurant
# 4   Mediterranean Restaurant               Pizza Place
# 5                       Café                     Hotel
# 6         Spanish Restaurant                     Hotel
# 7                     Bakery                     Hotel
# 8         Spanish Restaurant                    Hostel
# 9           Tapas Restaurant              Cocktail Bar
# 10                     Hotel          Tapas Restaurant
# 11                     Hotel                      Café
# 12                     Hotel            Clothing Store
# 13                     Plaza                     Hotel
# 14          Tapas Restaurant              Cocktail Bar
# 15            Scenic Lookout            Breakfast Spot
# 16              Cocktail Bar        Spanish Restaurant
# 17       Japanese Restaurant            Breakfast Spot
# 18          Tapas Restaurant              Cocktail Bar
# 19          Tapas Restaurant              Cocktail Bar
# 20          Tapas Restaurant              Cocktail Bar
# 21                    Bakery        Spanish Restaurant
# 22          Tapas Restaurant              Cocktail Bar
# 23                      Park          Tapas Restaurant
# 24                    Hostel                     Hotel
# 25          Tapas Restaurant        Spanish Restaurant
# 26            Clothing Store            Sandwich Place
# 27                     Hotel                      Café
# 28                Restaurant    Furniture / Home Store
# 29        Spanish Restaurant  Mediterranean Restaurant
# 30  Mediterranean Restaurant             Grocery Store
# 31                     Hotel                       Bar
# 32                     Hotel                Restaurant
# 33                Restaurant       Japanese Restaurant
# 34          Tapas Restaurant              Cocktail Bar
# 35                    Bakery                      Café
# 36  Mediterranean Restaurant                     Hotel
# 37                     Hotel                      Café
# 38          Tapas Restaurant        Spanish Restaurant
# 39          Tapas Restaurant              Cocktail Bar
# 40                Restaurant  Mediterranean Restaurant
# 41                     Hotel                      Café
#
#        3rd Most Common Venue 4th Most Common Venue     5th Most Common Venue  \
# 0   Mediterranean Restaurant            Restaurant                    Hostel
# 1               Cocktail Bar              Wine Bar        Italian Restaurant
# 2   Mediterranean Restaurant    Spanish Restaurant       Japanese Restaurant
# 3                Coffee Shop                 Plaza              Burger Joint
# 4                 Restaurant    Spanish Restaurant        Italian Restaurant
# 5         Spanish Restaurant            Restaurant             Grocery Store
# 6        Sporting Goods Shop        Soccer Stadium  Mediterranean Restaurant
# 7                 Restaurant    Italian Restaurant                 Gastropub
# 8                Coffee Shop             Rock Club                      Café
# 9                        Bar               Theater        Spanish Restaurant
# 10        Spanish Restaurant                   Bar              Cocktail Bar
# 11          Tapas Restaurant           Coffee Shop                    Hostel
# 12                 Bookstore            Restaurant  Mediterranean Restaurant
# 13          Tapas Restaurant        Ice Cream Shop        Spanish Restaurant
# 14                  Wine Bar                   Bar  Mediterranean Restaurant
# 15               Supermarket     French Restaurant                Food Truck
# 16                     Hotel            Restaurant  Mediterranean Restaurant
# 17  Mediterranean Restaurant                  Café        Italian Restaurant
# 18                  Wine Bar                   Bar  Mediterranean Restaurant
# 19  Mediterranean Restaurant    Spanish Restaurant                       Bar
# 20                  Wine Bar                   Bar  Mediterranean Restaurant
# 21               Pizza Place            Restaurant             Grocery Store
# 22                  Wine Bar                   Bar  Mediterranean Restaurant
# 23                     Hotel                Hostel                 Nightclub
# 24           Harbor / Marina                  Pier               Coffee Shop
# 25                     Plaza                 Hotel                      Café
# 26              Burger Joint    Spanish Restaurant             Women's Store
# 27                       Bar          Cocktail Bar                Restaurant
# 28              Cocktail Bar   Japanese Restaurant  Mediterranean Restaurant
# 29                Restaurant                 Hotel       Japanese Restaurant
# 30       Japanese Restaurant                 Hotel                Restaurant
# 31  Mediterranean Restaurant    Spanish Restaurant        Italian Restaurant
# 32  Mediterranean Restaurant           Coffee Shop       Japanese Restaurant
# 33               Coffee Shop        Sandwich Place                      Café
# 34                     Hotel                  Café  Mediterranean Restaurant
# 35              Burger Joint    Italian Restaurant            Breakfast Spot
# 36        Spanish Restaurant                Bakery                      Café
# 37                    Hostel            Restaurant               Coffee Shop
# 38                     Plaza                 Hotel                      Café
# 39                  Wine Bar                   Bar  Mediterranean Restaurant
# 40           Coworking Space                Market                      Park
# 41                Restaurant                Hostel               Coffee Shop
#
#        6th Most Common Venue          7th Most Common Venue  \
# 0           Tapas Restaurant                   Cocktail Bar
# 1                Pizza Place                   Dessert Shop
# 2           Tapas Restaurant                         Hostel
# 3                      Hotel                  Deli / Bodega
# 4                        Bar                         Bakery
# 5   Mediterranean Restaurant             Mexican Restaurant
# 6               Soccer Field                         Bakery
# 7   Mediterranean Restaurant                  Grocery Store
# 8                      Hotel                    Music Venue
# 9   Mediterranean Restaurant                           Café
# 10                 Bookstore  Vegetarian / Vegan Restaurant
# 11        Italian Restaurant                         Bistro
# 12          Tapas Restaurant                  Women's Store
# 13              Dessert Shop                           Café
# 14              Dessert Shop             Spanish Restaurant
# 15                Food Stand                     Food Court
# 16       Japanese Restaurant               Tapas Restaurant
# 17               Pizza Place             Spanish Restaurant
# 18              Dessert Shop             Spanish Restaurant
# 19                     Hotel                        Theater
# 20              Dessert Shop             Spanish Restaurant
# 21                      Café               Tapas Restaurant
# 22              Dessert Shop             Spanish Restaurant
# 23        Spanish Restaurant                    Pizza Place
# 24                      Park             Seafood Restaurant
# 25               Coffee Shop                            Bar
# 26      Fast Food Restaurant              Electronics Store
# 27               Coffee Shop       Mediterranean Restaurant
# 28          Tapas Restaurant             Spanish Restaurant
# 29                    Bakery               Tapas Restaurant
# 30                    Bakery                    Pizza Place
# 31            Breakfast Spot                           Café
# 32                   Brewery                            Gym
# 33        Spanish Restaurant                      Wine Shop
# 34                       Bar                   Dessert Shop
# 35          Tapas Restaurant                    Supermarket
# 36                     Diner                  Train Station
# 37          Tapas Restaurant                    Pizza Place
# 38               Coffee Shop                            Bar
# 39              Dessert Shop             Spanish Restaurant
# 40              Tennis Court                          Hotel
# 41        Spanish Restaurant               Tapas Restaurant
#
#        8th Most Common Venue          9th Most Common Venue  \
# 0                       Café                      Bookstore
# 1         Spanish Restaurant  Vegetarian / Vegan Restaurant
# 2                 Restaurant                  Women's Store
# 3                        Bar      Latin American Restaurant
# 4          Indian Restaurant              Food & Drink Shop
# 5           Tapas Restaurant                    Coffee Shop
# 6               Hockey Arena                   Cocktail Bar
# 7                Supermarket             Spanish Restaurant
# 8               Burger Joint               Tapas Restaurant
# 9                      Hotel                     Restaurant
# 10               Coffee Shop             Italian Restaurant
# 11                       Gym             Chinese Restaurant
# 12        Seafood Restaurant                   Cocktail Bar
# 13       Japanese Restaurant                      Gift Shop
# 14        Seafood Restaurant                    Coffee Shop
# 15         Food & Drink Shop                           Food
# 16            Sandwich Place                         Bakery
# 17        Mexican Restaurant                         Bakery
# 18        Seafood Restaurant                    Coffee Shop
# 19                Restaurant                       Wine Bar
# 20        Seafood Restaurant                    Coffee Shop
# 21  Mediterranean Restaurant                    Supermarket
# 22        Seafood Restaurant                    Coffee Shop
# 23              Cocktail Bar                 Scenic Lookout
# 24             Shopping Mall                         Museum
# 25  Mediterranean Restaurant                   Cocktail Bar
# 26            Cosmetics Shop                  Shopping Mall
# 27            Breakfast Spot                    Pizza Place
# 28                     Hotel                           Café
# 29                      Café                            Bar
# 30                  Wine Bar             Spanish Restaurant
# 31                Restaurant                         Bistro
# 32                 Nightclub                           Café
# 33  Mediterranean Restaurant                           Park
# 34                   Gay Bar                    Coffee Shop
# 35                  Wine Bar                        Brewery
# 36              Burger Joint                Doctor's Office
# 37  Mediterranean Restaurant                 Breakfast Spot
# 38  Mediterranean Restaurant                   Cocktail Bar
# 39        Seafood Restaurant                    Coffee Shop
# 40                      Food              Fondue Restaurant
# 41           Bed & Breakfast  Vegetarian / Vegan Restaurant
#
#       10th Most Common Venue
# 0         Spanish Restaurant
# 1   Mediterranean Restaurant
# 2                     Bakery
# 3                       Café
# 4                       Café
# 5                      Plaza
# 6                Coffee Shop
# 7                        Gym
# 8                     Bistro
# 9                   Beer Bar
# 10                      Café
# 11  Mediterranean Restaurant
# 12                    Bakery
# 13               Coffee Shop
# 14                     Hotel
# 15         Fondue Restaurant
# 16    Argentinian Restaurant
# 17         Indian Restaurant
# 18                     Hotel
# 19                      Café
# 20                     Hotel
# 21        Italian Restaurant
# 22                     Hotel
# 23       Moroccan Restaurant
# 24          Tapas Restaurant
# 25            Ice Cream Shop
# 26               Coffee Shop
# 27          Tapas Restaurant
# 28            Ice Cream Shop
# 29              Cocktail Bar
# 30                      Café
# 31               Music Venue
# 32        Spanish Restaurant
# 33                     Hotel
# 34              Burger Joint
# 35                    Hostel
# 36                      Park
# 37              Burger Joint
# 38            Ice Cream Shop
# 39                     Hotel
# 40         Food & Drink Shop
# 41               Supermarket

# %%
# Kmeans clustering
Kclusters = 10
barcelona_grouped_clustering= barcelona_grouped.drop('Neighbourhood',1)
#run k means
kmeans=KMeans(n_clusters=Kclusters, random_state=0).fit(barcelona_grouped_clustering)
kmeans.labels_[0:10]
# Out:
# array([1, 8, 1, 7, 7, 7, 7, 7, 7, 8], dtype=int32)

# %%
barcelona_merged=barna_df

barcelona_merged['Cluster Labels']=kmeans.labels_
neighbourhoods_venuessorted.shape
barcelona_merged=barcelona_merged.join(neighbourhoods_venuessorted.set_index('Neighbourhood'), on='Neighborhood')
barcelona_merged
# Out:
#     Postal Code                                       Neighborhood  Latitude  \
# 0          8001                                           El Raval   41.3818
# 1          8002                                     Gothic Quarter   41.3838
# 2          8003                       Ciutat Vella, La Barcelonata   41.3862
# 3          8004                                       El Poble Sec   41.3765
# 4          8005                                       El Poble Nou   41.3944
# 5          8006                       Sant Gervasi, Hospital Plato   41.3975
# 6          8007                     City Center, Passeig de Gracia   41.3900
# 7          8008                                           Diagonal   41.3936
# 8          8009    Girona, Jardins de Jaume Perich, Carrer d'Arago   41.3897
# 9          8010                        placa de Tetuan, Urquinaona   41.3902
# 10         8011                   Urgell,Jardin de Cesar Martinell   41.3836
# 11         8012                                     Vila de Gracia   41.3853
# 12         8013                        Fort Pienc, Sagrada Familia   41.3917
# 13         8014                  Sants, Taragona, Placa del Centre   41.3808
# 14         8015                              Sant Antoni, Rocafort   41.3815
# 15         8016                 Porta,Virrei Amat, La prosperitat    41.3853
# 16         8017                                        Vallvidrera   41.4003
# 17         8018     Sant Marti, La Verneda, Glories, Arc de Triomf   41.4008
# 18         8019           El Besos I El Maresme, Paolo Alto Market   41.4046
# 19         8020      La Verneda I La Pau, Sant Marti de Provencals   41.3833
# 20         8021       Sant Gervasi-Galvany, La Bonanova, Turo Parc   41.3952
# 21         8022  Sant Gervasi-La Bonanova, Av. Tibidabo,  El Pu...   41.3996
# 22         8023  Vallcarca I Els Penitents, El parc del Turo de...   41.4087
# 23         8024                         Gracia, Can Baro, Alfons X   41.3833
# 24         8025  El Baix Guinardo, El Camp D'En Grassot I Graci...   41.4048
# 25         8026                         El Camp de L'Arpa del Clot   41.3994
# 26         8027                                         La Sagrega   41.3833
# 27         8028  Les Corts, La Maternitat I Sant Ramon, Sants-M...   41.3818
# 28         8029            La Nova Esquerra de L'Exiample, Entenca   41.3860
# 29         8030                          Sant Adreu, Baro de Viver   41.4389
# 30         8031       Vilapicina, Can Peguera, El Turo de La Peira   41.3833
# 31         8032             El Carmel, Horta, La Font D'En Fargues   41.3844
# 32         8033  La Trinitat Nova, Trinitat Vella, Torre Baro, ...   41.3760
# 33         8034             Saria, Pedralbes, Ciutat Universitaria   41.3909
# 34         8035      Horta, Sant Genis Dels Agudells, La Teixonera   41.4296
# 35         8036                           Hospital Clinic, La Fira   41.3903
# 36         8037                    Verdaguer, Passeig de Sant Joan   41.3950
# 37         8038  Parc de Montjuic, La Marina de Port, La Marina...   41.3704
# 38         8039                                  Port de Barcelona   41.3723
# 39         8040                                        Zona Franca   41.3288
# 40         8041                                        El Guinardo   41.4137
# 41         8042                                       Les Roquetes   41.3833
#
#     Longitude  Cluster Labels     1st Most Common Venue  \
# 0      2.1685               1                     Hotel
# 1      2.1744               8                     Plaza
# 2      2.1799               1          Tapas Restaurant
# 3      2.1669               7          Tapas Restaurant
# 4      2.1874               7        Spanish Restaurant
# 5      2.1535               7                Restaurant
# 6      2.1682               7                     Hotel
# 7      2.1595               7                     Hotel
# 8      2.1660               7                     Hotel
# 9      2.1733               8                     Hotel
# 10     2.1607               2          Tapas Restaurant
# 11     2.1774               1          Tapas Restaurant
# 12     2.1782               1                     Hotel
# 13     2.1496               5                     Hotel
# 14     2.1599               8                     Hotel
# 15     2.1774               3          Tapas Restaurant
# 16     2.1277               2  Mediterranean Restaurant
# 17     2.1933               7                     Hotel
# 18     2.2068               8  Mediterranean Restaurant
# 19     2.1833               8          Tapas Restaurant
# 20     2.1462               8        Spanish Restaurant
# 21     2.1481               7  Mediterranean Restaurant
# 22     2.1444               8                    Bakery
# 23     2.1833               2          Tapas Restaurant
# 24     2.1763               6        Italian Restaurant
# 25     2.1757               5                      Café
# 26     2.1833               0          Tapas Restaurant
# 27     2.1324               2                    Bakery
# 28     2.1482               2       Japanese Restaurant
# 29     2.1973               7            Clothing Store
# 30     2.1833               7          Tapas Restaurant
# 31     2.1215               7        Spanish Restaurant
# 32     2.1666               7          Tapas Restaurant
# 33     2.1382               7                Restaurant
# 34     2.1342               2            Scenic Lookout
# 35     2.1574               9              Cocktail Bar
# 36     2.1728               7                     Hotel
# 37     2.1705               1                      Park
# 38     2.1795               5                    Hostel
# 39     2.1120               8                Restaurant
# 40     2.1776               4                    Bakery
# 41     2.1833               1          Tapas Restaurant
#
#        2nd Most Common Venue     3rd Most Common Venue 4th Most Common Venue  \
# 0           Tapas Restaurant        Spanish Restaurant                   Bar
# 1                      Hotel          Tapas Restaurant        Ice Cream Shop
# 2                        Bar              Cocktail Bar              Wine Bar
# 3               Cocktail Bar                       Bar               Theater
# 4                     Hostel               Coffee Shop             Rock Club
# 5     Furniture / Home Store              Cocktail Bar   Japanese Restaurant
# 6             Clothing Store  Mediterranean Restaurant            Restaurant
# 7                   Boutique  Mediterranean Restaurant    Spanish Restaurant
# 8             Clothing Store                 Bookstore            Restaurant
# 9                       Café                Restaurant                Hostel
# 10              Cocktail Bar                     Hotel                  Café
# 11        Spanish Restaurant                     Plaza                 Hotel
# 12                      Café          Tapas Restaurant           Coffee Shop
# 13                Restaurant  Mediterranean Restaurant           Coffee Shop
# 14                      Café                       Bar          Cocktail Bar
# 15        Spanish Restaurant                     Plaza                 Hotel
# 16                     Hotel        Spanish Restaurant                Bakery
# 17                       Bar  Mediterranean Restaurant    Spanish Restaurant
# 18               Pizza Place                Restaurant    Spanish Restaurant
# 19              Cocktail Bar                  Wine Bar                   Bar
# 20  Mediterranean Restaurant                Restaurant                 Hotel
# 21             Grocery Store       Japanese Restaurant                 Hotel
# 22                      Café              Burger Joint    Italian Restaurant
# 23              Cocktail Bar                  Wine Bar                   Bar
# 24                Restaurant               Coffee Shop                 Plaza
# 25                     Hotel        Spanish Restaurant            Restaurant
# 26              Cocktail Bar                  Wine Bar                   Bar
# 27        Spanish Restaurant               Pizza Place            Restaurant
# 28            Breakfast Spot  Mediterranean Restaurant                  Café
# 29            Sandwich Place              Burger Joint    Spanish Restaurant
# 30              Cocktail Bar                  Wine Bar                   Bar
# 31                     Hotel       Sporting Goods Shop        Soccer Stadium
# 32              Cocktail Bar  Mediterranean Restaurant    Spanish Restaurant
# 33       Japanese Restaurant               Coffee Shop        Sandwich Place
# 34            Breakfast Spot               Supermarket     French Restaurant
# 35        Spanish Restaurant                     Hotel            Restaurant
# 36                      Café                    Hostel            Restaurant
# 37          Tapas Restaurant                     Hotel                Hostel
# 38                     Hotel           Harbor / Marina                  Pier
# 39  Mediterranean Restaurant           Coworking Space                Market
# 40                     Hotel                Restaurant    Italian Restaurant
# 41              Cocktail Bar                  Wine Bar                   Bar
#
#        5th Most Common Venue     6th Most Common Venue  \
# 0               Cocktail Bar                 Bookstore
# 1         Spanish Restaurant              Dessert Shop
# 2         Italian Restaurant               Pizza Place
# 3         Spanish Restaurant  Mediterranean Restaurant
# 4                       Café                     Hotel
# 5   Mediterranean Restaurant          Tapas Restaurant
# 6                     Hostel          Tapas Restaurant
# 7        Japanese Restaurant          Tapas Restaurant
# 8   Mediterranean Restaurant          Tapas Restaurant
# 9                Coffee Shop        Spanish Restaurant
# 10  Mediterranean Restaurant                       Bar
# 11                      Café               Coffee Shop
# 12                    Hostel        Italian Restaurant
# 13       Japanese Restaurant                   Brewery
# 14                Restaurant               Coffee Shop
# 15                      Café               Coffee Shop
# 16                      Café                     Diner
# 17        Italian Restaurant            Breakfast Spot
# 18        Italian Restaurant                       Bar
# 19  Mediterranean Restaurant              Dessert Shop
# 20       Japanese Restaurant                    Bakery
# 21                Restaurant                    Bakery
# 22            Breakfast Spot          Tapas Restaurant
# 23  Mediterranean Restaurant              Dessert Shop
# 24              Burger Joint                     Hotel
# 25             Grocery Store  Mediterranean Restaurant
# 26  Mediterranean Restaurant              Dessert Shop
# 27             Grocery Store                      Café
# 28        Italian Restaurant               Pizza Place
# 29             Women's Store      Fast Food Restaurant
# 30  Mediterranean Restaurant              Dessert Shop
# 31  Mediterranean Restaurant              Soccer Field
# 32                       Bar                     Hotel
# 33                      Café        Spanish Restaurant
# 34                Food Truck                Food Stand
# 35  Mediterranean Restaurant       Japanese Restaurant
# 36               Coffee Shop          Tapas Restaurant
# 37                 Nightclub        Spanish Restaurant
# 38               Coffee Shop                      Park
# 39                      Park              Tennis Court
# 40                 Gastropub  Mediterranean Restaurant
# 41  Mediterranean Restaurant              Dessert Shop
#
#             7th Most Common Venue     8th Most Common Venue  \
# 0   Vegetarian / Vegan Restaurant               Coffee Shop
# 1                            Café       Japanese Restaurant
# 2                    Dessert Shop        Spanish Restaurant
# 3                            Café                     Hotel
# 4                     Music Venue              Burger Joint
# 5              Spanish Restaurant                     Hotel
# 6                    Cocktail Bar                      Café
# 7                          Hostel                Restaurant
# 8                   Women's Store        Seafood Restaurant
# 9                Tapas Restaurant           Bed & Breakfast
# 10                   Dessert Shop                   Gay Bar
# 11                            Bar  Mediterranean Restaurant
# 12                         Bistro                       Gym
# 13                            Gym                 Nightclub
# 14       Mediterranean Restaurant            Breakfast Spot
# 15                            Bar  Mediterranean Restaurant
# 16                  Train Station              Burger Joint
# 17                           Café                Restaurant
# 18                         Bakery         Indian Restaurant
# 19             Spanish Restaurant        Seafood Restaurant
# 20               Tapas Restaurant                      Café
# 21                    Pizza Place                  Wine Bar
# 22                    Supermarket                  Wine Bar
# 23             Spanish Restaurant        Seafood Restaurant
# 24                  Deli / Bodega                       Bar
# 25             Mexican Restaurant          Tapas Restaurant
# 26             Spanish Restaurant        Seafood Restaurant
# 27               Tapas Restaurant  Mediterranean Restaurant
# 28             Spanish Restaurant        Mexican Restaurant
# 29              Electronics Store            Cosmetics Shop
# 30             Spanish Restaurant        Seafood Restaurant
# 31                         Bakery              Hockey Arena
# 32                        Theater                Restaurant
# 33                      Wine Shop  Mediterranean Restaurant
# 34                     Food Court         Food & Drink Shop
# 35               Tapas Restaurant            Sandwich Place
# 36                    Pizza Place  Mediterranean Restaurant
# 37                    Pizza Place              Cocktail Bar
# 38             Seafood Restaurant             Shopping Mall
# 39                          Hotel                      Food
# 40                  Grocery Store               Supermarket
# 41             Spanish Restaurant        Seafood Restaurant
#
#             9th Most Common Venue    10th Most Common Venue
# 0              Italian Restaurant                      Café
# 1                       Gift Shop               Coffee Shop
# 2   Vegetarian / Vegan Restaurant  Mediterranean Restaurant
# 3                      Restaurant                  Beer Bar
# 4                Tapas Restaurant                    Bistro
# 5                            Café            Ice Cream Shop
# 6                       Bookstore        Spanish Restaurant
# 7                   Women's Store                    Bakery
# 8                    Cocktail Bar                    Bakery
# 9   Vegetarian / Vegan Restaurant               Supermarket
# 10                    Coffee Shop              Burger Joint
# 11                   Cocktail Bar            Ice Cream Shop
# 12             Chinese Restaurant  Mediterranean Restaurant
# 13                           Café        Spanish Restaurant
# 14                    Pizza Place          Tapas Restaurant
# 15                   Cocktail Bar            Ice Cream Shop
# 16                Doctor's Office                      Park
# 17                         Bistro               Music Venue
# 18              Food & Drink Shop                      Café
# 19                    Coffee Shop                     Hotel
# 20                            Bar              Cocktail Bar
# 21             Spanish Restaurant                      Café
# 22                        Brewery                    Hostel
# 23                    Coffee Shop                     Hotel
# 24      Latin American Restaurant                      Café
# 25                    Coffee Shop                     Plaza
# 26                    Coffee Shop                     Hotel
# 27                    Supermarket        Italian Restaurant
# 28                         Bakery         Indian Restaurant
# 29                  Shopping Mall               Coffee Shop
# 30                    Coffee Shop                     Hotel
# 31                   Cocktail Bar               Coffee Shop
# 32                       Wine Bar                      Café
# 33                           Park                     Hotel
# 34                           Food         Fondue Restaurant
# 35                         Bakery    Argentinian Restaurant
# 36                 Breakfast Spot              Burger Joint
# 37                 Scenic Lookout       Moroccan Restaurant
# 38                         Museum          Tapas Restaurant
# 39              Fondue Restaurant         Food & Drink Shop
# 40             Spanish Restaurant                       Gym
# 41                    Coffee Shop                     Hotel

# %%
# visulaize clusters
map_clusters=folium.Map(location=[latitude,longitude],zoom_start=12)
x = np.arange(Kclusters)
ys=[i+x+(i*x)**2 for i in range(Kclusters)]
colors_array=cm.rainbow(np.linspace(0,1,len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
#add markers
markers_colors=[]
for lat, lon, poi, cluster in zip(barcelona_merged['Latitude'],barcelona_merged['Longitude'], barcelona_merged['Neighborhood'], barcelona_merged['Cluster Labels']):
    label=folium.Popup(str(poi)+' Cluster '+str(cluster),parse_html=True)
    folium.CircleMarker(
        [lat,lon],
        radiesu=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we will input the prices of rent per square meters for each district and then cluster the neighborhoods to see which neighborhoods are most similar. The data over rent prices are from the last quarter of 2017 and have been obtained from Open Data BCN

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#         Dte.                                    Barris 1r Trimestre  \
# 0  BARCELONA                                       NaN           13
# 1          1                               1. el Raval         13,5
# 2          1                         2. el Barri Gòtic         14,1
# 3          1                         3. la Barceloneta         19,5
# 4          1  4. Sant Pere, Santa Caterina i la Ribera           15
#
#    2n Trimestre  3r Trimestre  4rt Trimestre  Acumulat/1r Trimestre  \
# 0           NaN           NaN            NaN                    NaN
# 1           NaN           NaN            NaN                    NaN
# 2           NaN           NaN            NaN                    NaN
# 3           NaN           NaN            NaN                    NaN
# 4           NaN           NaN            NaN                    NaN
#
#    Acumulat/2n Trimestre  Acumulat/3r Trimestre  Acumulat/4rt Trimestre
# 0                    NaN                    NaN                     NaN
# 1                    NaN                    NaN                     NaN
# 2                    NaN                    NaN                     NaN
# 3                    NaN                    NaN                     NaN
# 4                    NaN                    NaN                     NaN

# %%
df_data1 = df_data_2[df_data_2.columns[1:3]]
df_data3 = df_data1.rename(columns={'1r Trimestre': 'Price per sq. m'})
df_data3.head()
# Out:
#                                      Barris Price per sq. m
# 0                                       NaN              13
# 1                               1. el Raval            13,5
# 2                         2. el Barri Gòtic            14,1
# 3                         3. la Barceloneta            19,5
# 4  4. Sant Pere, Santa Caterina i la Ribera              15

# %%
df_data3.drop(df_data3.index[0], inplace=True)

# %%
df_data4 = df_data3[df_data3['Price per sq. m'].str.contains("nd") == False] # droppinf rows with NaN or Nd values 
# next step is to select only those rows which partially match the rows of the main barcelona Table
# cleaning the data
df_data4.loc[:,'Barris']= [x.split('.')[1] for x in df_data4['Barris']]
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
# adding the datasets manually
df5 = barcelona_merged
df5['Rent per sq m'] = 1
df5['Rent per sq m'][1]  = 19.5
df5['Rent per sq m'][10] = 13.5
df5['Rent per sq m'][13] = 14.1
df5['Rent per sq m'][11] = 13
df5['Rent per sq m'][17] = 13
df5['Rent per sq m'][0]  = 19.8
df5['Rent per sq m'][3]  = 12.7
df5['Rent per sq m'][2]  = 12.3
df5['Rent per sq m'][4]  = 9.5
df5['Rent per sq m'][5]  = 12.9
df5['Rent per sq m'][6]  = 11.2
df5['Rent per sq m'][7]  = 19.5
df5['Rent per sq m'][8]  = 13.4
df5['Rent per sq m'][9]  = 13
df5['Rent per sq m'][11] = 13.5
df5['Rent per sq m'][12] = 12.8
df5['Rent per sq m'][14] = 11.9
df5['Rent per sq m'][15] = 11.2
df5['Rent per sq m'][16] = 13.2
df5['Rent per sq m'][18] = 9.8
df5['Rent per sq m'][19] = 10
df5['Rent per sq m'][20] = 13.2
df5['Rent per sq m'][21] = 13.6
df5['Rent per sq m'][22] = 9.4
df5['Rent per sq m'][23] = 9.9
df5['Rent per sq m'][24] = 11.5
df5['Rent per sq m'][25] = 11.6
df5['Rent per sq m'][26] = 12.4
df5['Rent per sq m'][27] = 12.4
df5['Rent per sq m'][28] = 14.5
df5['Rent per sq m'][29] = 14.6
df5['Rent per sq m'][30] = 15
df5['Rent per sq m'][31] = 13.2
df5['Rent per sq m'][32] = 12.4
df5['Rent per sq m'][33] = 16
df5['Rent per sq m'][34] = 14
df5['Rent per sq m'][35] = 14.1
df5['Rent per sq m'][36] = 10.1
df5['Rent per sq m'][37] = 9.8
df5['Rent per sq m'][38] = 14.9
df5['Rent per sq m'][39] = 11.2
df5['Rent per sq m'][40] = 11.1
df5['Rent per sq m'][41] = 13.7

# %%
df5.head()
# Out:
#    Postal Code                  Neighborhood  Latitude  Longitude  \
# 0         8001                      El Raval   41.3818     2.1685
# 1         8002                Gothic Quarter   41.3838     2.1744
# 2         8003  Ciutat Vella, La Barcelonata   41.3862     2.1799
# 3         8004                  El Poble Sec   41.3765     2.1669
# 4         8005                  El Poble Nou   41.3944     2.1874
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               1                 Hotel      Tapas Restaurant
# 1               8                 Plaza                 Hotel
# 2               1      Tapas Restaurant                   Bar
# 3               7      Tapas Restaurant          Cocktail Bar
# 4               7    Spanish Restaurant                Hostel
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0    Spanish Restaurant                   Bar          Cocktail Bar
# 1      Tapas Restaurant        Ice Cream Shop    Spanish Restaurant
# 2          Cocktail Bar              Wine Bar    Italian Restaurant
# 3                   Bar               Theater    Spanish Restaurant
# 4           Coffee Shop             Rock Club                  Café
#
#       6th Most Common Venue          7th Most Common Venue  \
# 0                 Bookstore  Vegetarian / Vegan Restaurant
# 1              Dessert Shop                           Café
# 2               Pizza Place                   Dessert Shop
# 3  Mediterranean Restaurant                           Café
# 4                     Hotel                    Music Venue
#
#   8th Most Common Venue          9th Most Common Venue  \
# 0           Coffee Shop             Italian Restaurant
# 1   Japanese Restaurant                      Gift Shop
# 2    Spanish Restaurant  Vegetarian / Vegan Restaurant
# 3                 Hotel                     Restaurant
# 4          Burger Joint               Tapas Restaurant
#
#      10th Most Common Venue  Rent per sq m
# 0                      Café             19
# 1               Coffee Shop             19
# 2  Mediterranean Restaurant             12
# 3                  Beer Bar             12
# 4                    Bistro              9

# %%
# normalizing the rent column
def standardize( df, label):
    """
    standardizes a series with name ``label'' within the pd.DataFrame
    ``df''.
    """
    df = df.copy(deep=True)
    series = df.loc[:, label]
    avg = series.mean()
    stdv = series.std()
    series_standardized = (series - avg)/ stdv
    return series_standardized
Out = standardize(df5, 'Rent per sq m')
new=[]
for i in df5['Rent per sq m']:
    new.append(Out[i])

# %%
# final result , Hence we can show the similarity or dissimilarity between different neighborhoods alongwith Rent prices, whcih will recommend the person where to get a house
df5['Rent per sq m'] = new

# %%
df5.head()
# Out:
#    Postal Code                  Neighborhood  Latitude  Longitude  \
# 0         8001                      El Raval   41.3818     2.1685
# 1         8002                Gothic Quarter   41.3838     2.1744
# 2         8003  Ciutat Vella, La Barcelonata   41.3862     2.1799
# 3         8004                  El Poble Sec   41.3765     2.1669
# 4         8005                  El Poble Nou   41.3944     2.1874
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               1                 Hotel      Tapas Restaurant
# 1               8                 Plaza                 Hotel
# 2               1      Tapas Restaurant                   Bar
# 3               7      Tapas Restaurant          Cocktail Bar
# 4               7    Spanish Restaurant                Hostel
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0    Spanish Restaurant                   Bar          Cocktail Bar
# 1      Tapas Restaurant        Ice Cream Shop    Spanish Restaurant
# 2          Cocktail Bar              Wine Bar    Italian Restaurant
# 3                   Bar               Theater    Spanish Restaurant
# 4           Coffee Shop             Rock Club                  Café
#
#       6th Most Common Venue          7th Most Common Venue  \
# 0                 Bookstore  Vegetarian / Vegan Restaurant
# 1              Dessert Shop                           Café
# 2               Pizza Place                   Dessert Shop
# 3  Mediterranean Restaurant                           Café
# 4                     Hotel                    Music Venue
#
#   8th Most Common Venue          9th Most Common Venue  \
# 0           Coffee Shop             Italian Restaurant
# 1   Japanese Restaurant                      Gift Shop
# 2    Spanish Restaurant  Vegetarian / Vegan Restaurant
# 3                 Hotel                     Restaurant
# 4          Burger Joint               Tapas Restaurant
#
#      10th Most Common Venue  Rent per sq m
# 0                      Café      -1.036621
# 1               Coffee Shop      -1.036621
# 2  Mediterranean Restaurant      -0.230360
# 3                  Beer Bar      -0.230360
# 4                    Bistro       0.172770
